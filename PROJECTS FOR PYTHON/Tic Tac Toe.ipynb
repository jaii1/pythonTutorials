# %%
from tkinter import *
# import tkinter as TK()
import tkinter.messagebox
board =TK()
board.title('Tic toe games')
player_1 =strvar()
player_2 =strvar()
ptr1 =0
ptr2=0
flag = True
ctrl=1

def play(btn):
    global flag,ctrl
    if btn['text'] == " " and flag == True:
        flag=False
        btn['text']= 'x'
        ctrl+=1
        check()
    elif btn['text'] == " " and flag == False:
        flag =True
        btm['text'] = 'o'
        ctrl+=1
        check()
    else:
        tkinter.messagebox.showinfo("LearnTechToTech", "Not Allowed")
def clearButton():
    button1['text'] =" "
    button2['text'] =" "
    button3['text'] =" "
    button4['text'] =" "
    button5['text'] =" "
    button6['text'] =" "
    button7['text'] =" "
    button8['text']= " "
    button9['text']=" "
    
def check():
    global player_1,player2,ptr1,ptr2,ctrl
    if(button1['text'] == 'x' and button2['text']=='x'and button3['text']=='x' or
      button4['text']=='x' and button5['text']=='x' and button6['text']=='x' or
      button7['text']=='x'and button8['text']=='x'and button9['text']=='x' or 
      button7['text']=='x'and button8['text']=='x'and button9['text']=='x' or
      button1['text']=='x'and button5['text']=='x'and button9['text']=='x' or
      button3['text']=='x'and button5['text']=='x'and button7['text']=='x' or
      button1['text']=='x'and button4['text']=='x'and button7['text']=='x' or
      button2['text']=='x'and button5['text']=='x'and button8['text']=='x' or
      button3['text']=='x'and button6['text']=='x'and button9['text']==     'x'
       clearButton()
       tkinter.messagebox.showinfo('Tic Tac Toe', 'Player_1 Win')
       ptr1+=1
       ctrl=0
      
       player_1.set(ptr1)
  
       
       
    elif (button1['text'] == 'o' and button2['text']=='o'and button3['text']=='o' or
      button4['text']=='o' and button5['text']=='o' and button6['text']=='o' or
      button7['text']=='o'and button8['text']=='o'and button9['text']=='o' or 
      button7['text']=='o'and button8['text']=='o'and button9['text']=='o' or
      button1['text']=='o'and button5['text']=='o'and button9['text']=='o' or
      button3['text']=='o'and button5['text']=='o'and button7['text']=='o' or
      button1['text']=='o'and button4['text']=='o'and button7['text']=='o' or
      button2['text']=='o'and button5['text']=='o'and button8['text']=='o' or
      button3['text']=='o'and button6['text']=='o'and button9['text']=='o'
          clearButton()
          tkinter.messagebox.showinfo('Tic Tac Toe', 'Player_2 Win')
          ptr2+=1
          ctrl=0
          player_2.set(ptr2)

    elif (ctrl==8):
        tkinter.messagebx.showinfo('Tic Tac Toe', 'It is a Tie')
    

    
        

button1= button(board,text=" ",font='Times 15 bold',bg='Red',fg='White',bd=5,height=3,width=5,
                command =lambda:play(btn)
button1.grid(row=1,column=0)
button2= button(board,text=" ",font='Times 15 bold',bg='Red',fg='White',bd=5,height=3,width=5,
                command =lambda:play(btn)
button2.grid(row=1,column=1)
button3= button(board,text=" ",font='Times 15 bold',bg='Red',fg='White',bd=5,height=3,width=5,
                command =lambda:play(btn)
button3.grid(row=1,column=2)
button4= button(board,text=" ",font='Times 15 bold',bg='Red',fg='White',bd=5,height=3,width=5,
                command =lambda:play(btn)
button4.grid(row=2,column=0)                
button5= button(board,text=" ",font='Times 15 bold',bg='Red',fg='White',bd=5,height=3,width=5,
                command =lambda:play(btn)
button5.grid(row=2,column=1)       
button6= button(board,text=" ",font='Times 15 bold',bg='Red',fg='White',bd=5,height=3,width=5,
                command =lambda:play(btn)
button6.grid(row=2,column=2)
button7= button(board,text=" ",font='Times 15 bold',bg='Red',fg='White',bd=5,height=3,width=5,
                command =lambda:play(btn)
button7.grid(row=3,column=0)
button8= button(board,text=" ",font='Times 15 bold',bg='Red',fg='White',bd=5,height=3,width=5,
                command =lambda:play(btn)
button8.grid(row=3,column=1)
button9= button(board,text=" ",font='Times 15 bold',bg='Red',fg='White',bd=5,height=3,width=5,
                command =lambda:play(btn)
button9.grid(row=3,column=2)
board.mainloop()
# Out:
#   File "<ipython-input-9-66efd85171ba>", line 49
#     clearButton()
#     ^
# SyntaxError: invalid syntax

# %%
# Image Process is a method to performs some operations on the image in order to enhanced high quality image or 
# to extract most useful information from that
In this we give image as a input and output as features associated with that image

# %%
openCV is a open source python Library which focused on image processing and real-time video capturing to detect face and 
objects
How Image work in computer-it converts image into array of pixel values and where the dimension(shape) of the array(row,columns) 
(entire array of pixel values) depends upon the resolution of the Image(whether it is black in white or coloured image)
eg- Array of dimension is 32*32*3(RGB) is for coloured image 
Array of dimension is 32*32 (for blackinwhite image)

# %%
openCV reads a given image in the BGR format by default.So we need to change the colour space of your image from BGR TO RGB
wen reading images using openCV
colour spaces like RGB,BGR,HSV can manually be converted by using openCV function called cvtColor()--c in caps

# %%
import cv2
cv2.__version__
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 1 value for colour image
# 0 for grayscale image
img = cv2.imread('C:/Users/DELL/Downloads/Beautiful-girl-with-gentle-smile.jpg',1)
img2 = cv2.imread('C:/Users/DELL/Downloads/Beautiful-girl-with-gentle-smile.jpg', 0)
plt.imshow(img)

# %%
# u can see computer read image as a array of values
print(img)
# Out:
# [[[ 72  85 101]
#   [ 73  86 102]
#   [ 74  87 103]
#   ...
#   [113 119 130]
#   [113 119 130]
#   [113 119 130]]
#
#  [[ 72  85 101]
#   [ 73  86 102]
#   [ 74  87 103]
#   ...
#   [112 118 129]
#   [112 118 129]
#   [112 118 129]]
#
#  [[ 73  86 102]
#   [ 74  87 103]
#   [ 75  88 104]
#   ...
#   [112 118 129]
#   [112 118 129]
#   [112 118 129]]
#
#  ...
#
#  [[ 55  59  70]
#   [ 53  57  68]
#   [ 51  55  66]
#   ...
#   [ 41  48  68]
#   [ 51  58  78]
#   [ 43  50  70]]
#
#  [[ 42  46  57]
#   [ 40  44  55]
#   [ 39  43  54]
#   ...
#   [ 38  45  65]
#   [ 49  56  76]
#   [ 41  48  68]]
#
#  [[ 31  35  46]
#   [ 30  34  45]
#   [ 28  32  43]
#   ...
#   [ 37  44  64]
#   [ 48  55  75]
#   [ 40  47  67]]]
# (460, 340, 3)

# %%
# finding out dimension or shape(rows,columns) of the above entire array of pixel value which is depends upon
# resolutuion of image(color or grey)
# here 3  so it is coloured image has 3 values for each pixel red,green,blue channel
img.shape
# Out:
# (460, 340, 3)

# %%
# 0 for gray scale image(black n white)
img2 = cv2.imread('C:/Users/DELL/Downloads/Beautiful-girl-with-gentle-smile.jpg', 0)
plt.imshow(img2)

# %%
# now reading and checking its shape
print(img2)
# now checking its array of pixel value shape(dimension)
img2.shape
# It has single pixel value(gray scale image)
# Out:
# [[ 88  89  90 ... 122 122 122]
#  [ 88  89  90 ... 121 121 121]
#  [ 89  90  91 ... 121 121 121]
#  ...
#  [ 62  60  58 ...  53  63  55]
#  [ 49  47  46 ...  50  61  53]
#  [ 38  37  35 ...  49  60  52]]
# (460, 340)

# %%
# NOW CONVERTING COLOR IMAGE INTO GRAY SCALE IMAGE
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray_image)

# %%
# HSV color space ,application like video compression and device independence storage totally depends upon HSV
# in this color and intenity information are separated from each other

# %%
# NOW CONVERTING COLOR IMAGE TO HSV FORMAT(HSV TO UNDERSTAND COLOR SPACE AND INTENSITY DIFFERENTLY)
img4 = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
plt.imshow(img4)

# %%
print(img4)
# Out:
# [[[ 13  73 101]
#   [ 13  73 102]
#   [ 13  72 103]
#   ...
#   [ 11  33 130]
#   [ 11  33 130]
#   [ 11  33 130]]
#
#  [[ 13  73 101]
#   [ 13  73 102]
#   [ 13  72 103]
#   ...
#   [ 11  34 129]
#   [ 11  34 129]
#   [ 11  34 129]]
#
#  [[ 13  73 102]
#   [ 13  72 103]
#   [ 13  71 104]
#   ...
#   [ 11  34 129]
#   [ 11  34 129]
#   [ 11  34 129]]
#
#  ...
#
#  [[  8  55  70]
#   [  8  56  68]
#   [  8  58  66]
#   ...
#   [  8 101  68]
#   [  8  88  78]
#   [  8  98  70]]
#
#  [[  8  67  57]
#   [  8  70  55]
#   [  8  71  54]
#   ...
#   [  8 106  65]
#   [  8  91  76]
#   [  8 101  68]]
#
#  [[  8  83  46]
#   [  8  85  45]
#   [  8  89  43]
#   ...
#   [  8 108  64]
#   [  8  92  75]
#   [  8 103  67]]]

# %%
img4.shape
# Out:
# (460, 340, 3)

# %%
# now to resize your image(here color image)
smaller_size_image = cv2.resize(img, (50,50))
plt.imshow(smaller_size_image)

# %%
ret,thresh_binary = cv2.threshold(gray_image,127,255,cv2.THRESH_BINARY)
ret,thresh_binary_inv = cv2.threshold(gray_image,127,255,cv2.THRESH_BINARY_INV)
ret,thresh_trunc = cv2.threshold(gray_image,127,255,cv2.THRESH_TRUNC)
ret,thresh_tozero = cv2.threshold(gray_image, 127,255,cv2.THRESH_TOZERO)
ret,thresh_tozero_inv =cv2.threshold(gray_image,127,255,cv2.THRESH_TOZERO_INV)

# %%
# displaying difernt threshold style using openCV
names =["Original image",'BINARY','THRESH_BINARY', 'THRESH_TRUNC','THRESH_TOZERO', 'THRESH_TOZERO_INV']
images = gray_image,thresh_binary,thresh_binary_inv,thresh_trunc,thresh_tozero,thresh_tozero_inv
for i in range(6):
    plt.subplot(2,3,i+1),plt.imshow(images[i],'gray')
    plt.title(names[i])
    plt.xticks([]),plt.yticks([])

# %%
# CASCADE , FIRST WE DOWNLOAD IMAGE FILE HAARCASCADE_FRONTALFACE_DEFAULT FROM GOOGLE

# %%
face_cascade = cv2.CascadeClassifier("http://haarcascadefrontaldefault")
face = face_cascade.detectMultiScale(img, 1.1,4)
for i in (x,y,w,h):
    cv2.rectangle(img,(x,y),(x+w, y+h),(255,0,0),2)
    cv2.imshow(img)
    cv2.waitkey()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-d553894491dc> in <module>
#       1 face_cascade = cv2.CascadeClassifier("http://haarcascadefrontaldefault")
# ----> 2 face = face_cascade.detectMultiScale(image, 1.1,4)
#       3 for i in (x,y,w,h):
#       4     cv2.rectangle(img,(x,y),(x+w, y+h),(255,0,0),2)
#       5     cv2.imshow(img)
#
# NameError: name 'image' is not defined

# %%
SIMILIARLY I WILL USE ANOTHER IMAGE AND THEN CONVERTED INTO GRAY AND THEN USE 
face = face_cascade.detectMultiScale(gray,1.1,4)
